# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
model_loading = {"CPU+FP32": 0.6453, "CPU+FP16": 0.6771, "CPU+INT8": 1.4655, "HETERO:GPU,CPU+FP16": 71.6816}

# %%
model_loading.keys()
# Out:
# dict_keys(['CPU+FP32', 'CPU+FP16', 'CPU+INT8', 'HETERO:GPU,CPU+FP16'])

# %%
model_loading.values()
# Out:
# dict_values([0.6453, 0.6771, 1.4655, 71.6816])

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(model_loading.keys(), model_loading.values(), width=0.6)
plt.xlabel("Device and Model Precision")
plt.ylabel("Model Loading Time in Seconds")
# Out:
# Text(0, 0.5, 'Model Loading Time in Seconds')

# %%
model_input_time = {"CPU+FP32": 0.0575, "CPU+FP16": 0.0553, "CPU+INT8": 0.0545, "HETERO:GPU,CPU+FP16": 0.0547}

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(model_input_time.keys(), model_input_time.values(), width=0.6)
plt.xlabel("Device and Model Precision")
plt.ylabel("Model Input Time in Seconds")
# Out:
# Text(0, 0.5, 'Model Input Time in Seconds')

# %%
model_infer_time = {"CPU+FP32": 0.0201, "CPU+FP16": 0.0197, "CPU+INT8": 0.0183, "HETERO:GPU,CPU+FP16": 0.0251}
fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(model_infer_time.keys(), model_infer_time.values(), width=0.6)
plt.xlabel("Device and Model Precision")
plt.ylabel("Model Inference Time in Seconds")
plt.ylim(0, 0.1)
# Out:
# (0.0, 0.1)

# %%
mouse_control_time = {"CPU+FP32": 1.1740, "CPU+FP16": 1.1730, "CPU+INT8": 1.1723, "HETERO:GPU,CPU+FP16": 1.1707}
fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(mouse_control_time.keys(), mouse_control_time.values(), width=0.6)
plt.xlabel("Device and Model Precision")
plt.ylabel("Mouse controller Run Time in Seconds")
plt.ylim(0, 1.5)
# Out:
# (0.0, 1.5)

# %%
# CPU, FP32
CPU_FP32 = {"model loading time":  0.6453, "input_time/frame":  0.0575, 
            "inference time/frame":  0.0201, "mouse controlling time/frame":  1.1740}

# %%
CPU_FP32.keys()
# Out:
# dict_keys(['model loading time', 'input_time/frame', 'inference time/frame', 'mouse controlling time/frame'])

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.bar(CPU_FP32.keys(), CPU_FP32.values(), width=0.6)
plt.xlabel("App Running Steps")
plt.ylabel("Running Time in Seconds")
# Out:
# Text(0, 0.5, 'Running Time in Seconds')
